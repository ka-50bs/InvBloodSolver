# %% [markdown]
# ### Подключение библиотек

# %%
import pandas as pd
import numpy as np
import re
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.neighbors import KDTree
import random
import matplotlib.pyplot as plt
import time
import pickle
from IPython.display import Image

# %% [markdown]
# ### Теоретический набор датасетов (синтетические)

# %%
df_th = pd.read_csv(r'c:\Users\trrak\OneDrive\Рабочий стол\platelets\project_FC\BD_platelets_regular.csv', sep=';')
df_th
# Out:
#           r  eps       n  beta              0            0.5              1  \
# 0       0.5  0.1  1.3725    40      25.301178      25.209944      24.938040
# 1       0.5  0.1  1.3725    42      25.253750      25.164614      24.898931
# 2       0.5  0.1  1.3725    44      25.202293      25.115267      24.855852
# 3       0.5  0.1  1.3725    46      25.143423      25.058531      24.805452
# 4       0.5  0.1  1.3725    48      25.076042      24.993305      24.746632
# ...     ...  ...     ...   ...            ...            ...            ...
# 196139  2.1  1.0  1.3875    82  214711.812500  212251.640600  205016.031300
# 196140  2.1  1.0  1.3875    84  214710.484400  212250.328100  205014.765600
# 196141  2.1  1.0  1.3875    86  214710.375000  212250.218800  205014.671900
# 196142  2.1  1.0  1.3875    88  214711.218800  212251.046900  205015.484400
# 196143  2.1  1.0  1.3875    90  214711.406300  212251.234400  205015.656300
#
# ...

# %%
# Вывод количества строк с пустыми значениями
rows_with_null = df_th.isnull().any(axis=1).sum()

print("Общее количество строк с пустыми значениями:", rows_with_null)
# Out:
# Общее количество строк с пустыми значениями: 0

# %%
# Удаление колонок, у которых не целый шаг (есть точка в названии)
columns_to_remove = [column for column in df_th.columns if re.search(r'\.', column)]
df_th = df_th.drop(columns_to_remove, axis=1)

# %%
columns_to_keep = ['r', 'eps', 'n', 'beta'] + [str(column) for column in range(10, 70)]
df_th = df_th[columns_to_keep]

# %%
df_th
# Out:
#           r  eps       n  beta           10           11           12  \
# 0       0.5  0.1  1.3725    40     5.404986     3.808764     2.571659
# 1       0.5  0.1  1.3725    42     5.638411     4.030185     2.771908
# 2       0.5  0.1  1.3725    44     5.882321     4.264443     2.986821
# 3       0.5  0.1  1.3725    46     6.136376     4.511734     3.217116
# 4       0.5  0.1  1.3725    48     6.400964     4.772917     3.464140
# ...     ...  ...     ...   ...          ...          ...          ...
# 196139  2.1  1.0  1.3875    82  1469.599243  2256.340088  2440.665527
# 196140  2.1  1.0  1.3875    84  1469.591797  2256.213867  2440.489990
# 196141  2.1  1.0  1.3875    86  1469.587891  2256.108643  2440.339111
# 196142  2.1  1.0  1.3875    88  1469.594604  2256.052246  2440.252686
# 196143  2.1  1.0  1.3875    90  1469.605347  2256.039795  2440.226318
#
#                  13           14          15  ...        60        61  \
# ...

# %% [markdown]
# ### Визуализация теоретических данных

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 4, figsize=(12, 3))

# Построение графиков для каждой колонки
axes[0].hist(df_th['r'], bins=100)
axes[0].set_xlabel('r')
axes[0].set_ylabel('Частота')
axes[0].set_title('Распределение r')

axes[1].hist(df_th['eps'], bins=100)
axes[1].set_xlabel('eps')
axes[1].set_ylabel('Частота')
axes[1].set_title('Распределение eps')

axes[2].hist(df_th['n'], bins=100)
axes[2].set_xlabel('n')
axes[2].set_ylabel('Частота')
axes[2].set_title('Распределение n')

axes[3].hist(df_th['beta'], bins=100)
axes[3].set_xlabel('beta')
axes[3].set_ylabel('Частота')
axes[3].set_title('Распределение beta')

plt.tight_layout()  # Расстановка графиков без перекрытия
plt.show()

# %% [markdown]
# ### Экспериментальный набор датасетов

# %%
df_ex = pd.read_csv(r'c:\Users\trrak\OneDrive\Рабочий стол\platelets\project_FC\experimental_1_degree.csv', sep=';')
df_ex
# Out:
#                 10          11          12          13          14  \
# 0       183.176875  166.478693  134.478772  116.654527   98.472286
# 1        74.758799   72.793755   65.249161   66.274876   59.231701
# 2       878.528295  608.147687  422.259021  284.829020  174.500711
# 3       555.969393  431.583247  345.706680  280.833703  231.427627
# 4       340.091255  268.053440  213.270653  170.341848  128.769485
# ...            ...         ...         ...         ...         ...
# 17436  1377.752719  878.281592  546.089727  325.884113  165.992291
# 17437   415.114219  318.059332  250.199157  188.483128  143.479386
# 17438   733.036042  478.025693  310.075502  203.592574  106.704587
# 17439   629.617094  426.788555  301.349396  201.641640  127.522228
# 17440   370.467478  300.857278  220.421709  177.753386  131.407252
#
#                15          16          17         18         19  ...  \
# 0       78.717751   62.504292   57.866845  49.507113  45.329470  ...
# ...

# %%
# Вывод количества строк с пустыми значениями
rows_with_null = df_ex.isnull().any(axis=1).sum()

print("Общее количество строк с пустыми значениями:", rows_with_null)
# Out:
# Общее количество строк с пустыми значениями: 17441

# %%
df_ex = df_ex.drop('70', axis=1)

# %% [markdown]
# #### Получаем датафреймы для сравнения алгоритмов быстрого поиска со стандартным

# %% [markdown]
# Деление теоретических данных

# %%
X = df_th.iloc[:, 4:]
y = df_th[['r', 'eps', 'n', 'beta']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.02, random_state=42, shuffle=True)

# %%
# Преобразование в массив
X_train_array = X_train.values
X_test_array = X_test.values
y_train_array = y_train.values
y_test_array = y_test.values

# %% [markdown]
# Деление экспериментальных данных

# %%
X_th_array = df_th.iloc[:, 4:].values
y_th_array = df_th[['r', 'eps', 'n', 'beta']].values
X_exp_array = df_ex.values

# %% [markdown]
# Сохранение массивов (их будем использовать для bd_search и alg_search)

# %%
# для теоретических данных
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_th" + "\X_train_array.npy", X_train_array)
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_th" + "\X_test_array.npy", X_test_array)
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_th" + "\y_train_array.npy", y_train_array)
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_th" + "\y_test_array.npy", y_test_array)

# для экспериментальных данных
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_exp1" + "\X_th_array.npy", X_th_array)
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_exp1" + "\y_th_array.npy", y_th_array)
np.save(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_exp1" + "\X_exp_array.npy", X_exp_array)

# %% [markdown]
# ### Сравнение метода bd_search и alg_search по индексам и времени

# %% [markdown]
# Сравнение теоретических данных

# %%
with open(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\bd_search_files\index_th.txt", "r") as file:
    lines = file.read().split("\n")
    index_th_bd = [int(float(line)) for line in lines if line.strip()]

with open(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\alg_search_files\index_th.txt", "r") as file:
    lines = file.read().split("\n")
    index_th_alg = [int(float(line)) for line in lines if line.strip()]

# %%
data = {
    "index_th_bd": index_th_bd,
    "index_th_alg": index_th_alg
}

compare_th = pd.DataFrame(data)

# Добавляем колонку "Different" с результатами сравнения
compare_th["different"] = compare_th["index_th_bd"] != compare_th["index_th_alg"]

# Вычисляем процент True в колонке "different"
true_percentage = (compare_th["different"].sum() / len(compare_th)) * 100

print(f"Процент соответствия по индексам: {true_percentage:.2f}%")
# Out:
# Процент соответствия по индексам: 0.00%

# %% [markdown]
# Сравнение эксперименальных данных

# %%
with open(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\bd_search_files\index_exp.txt", "r") as file:
    lines = file.read().split("\n")
    index_exp_bd = [int(float(line)) for line in lines if line.strip()]

with open(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\alg_search_files\index_exp.txt", "r") as file:
    lines = file.read().split("\n")
    index_exp_alg = [int(float(line)) for line in lines if line.strip()]

# %%
data = {
    "index_exp_bd": index_exp_bd,
    "index_exp_alg": index_exp_alg
}

compare_exp = pd.DataFrame(data)

# Добавляем колонку "Different" с результатами сравнения
compare_exp["different"] = compare_exp["index_exp_bd"] != compare_exp["index_exp_alg"]

# Вычисляем процент True в колонке "different"
true_percentage = (compare_exp["different"].sum() / len(compare_exp)) * 100

print(f"Процент соответствия по индексам: {true_percentage:.2f}%")
# Out:
# Процент соответствия по индексам: 0.01%

# %% [markdown]
# ### Выведем корреляцию выходных параметров на теоретических тестовых данных

# %%
y_test_array = np.load(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_th\y_test_array.npy")
y_test_array.shape
# Out:
# (3923, 4)

# %%
print(len(index_th_alg))
# Out:
# 3923

# %%
y
# Out:
#           r  eps       n  beta
# 0       0.5  0.1  1.3725    40
# 1       0.5  0.1  1.3725    42
# 2       0.5  0.1  1.3725    44
# 3       0.5  0.1  1.3725    46
# 4       0.5  0.1  1.3725    48
# ...     ...  ...     ...   ...
# 196139  2.1  1.0  1.3875    82
# 196140  2.1  1.0  1.3875    84
# 196141  2.1  1.0  1.3875    86
# 196142  2.1  1.0  1.3875    88
# 196143  2.1  1.0  1.3875    90
#
# [196144 rows x 4 columns]

# %%
y_array = y.values
y_pred = y_array[index_th_alg]

# %% [markdown]
# Дальше проблемки

# %%
y_test_array.T[0]
# Out:
# array([1.89999998, 1.34000003, 0.74000001, ..., 0.66000003, 0.94      ,
#        1.01999998])

# %%
plt.plot(y_test_array.T[0], y_pred.T[0], '.')
plt.xlabel('Индексы')
plt.ylabel('Значения')
plt.title('График y_data')
plt.grid(True)
plt.show()

# %%
y_pred.T[0]
# Out:
# array([1.94000006, 0.57999998, 1.38      , ..., 1.13999999, 1.98000002,
#        0.54000002])

# %%
y_test_array.shape
# Out:
# (39229, 4)

# %%
y_pred.shape
# Out:
# (39229, 4)

# %%
def regr_model_resume(_y_test, _y_pred, params = ['r','eps', 'n', 'beta'], _title = '___________'):
    import matplotlib.pyplot as plt
    from sklearn.metrics import mean_squared_error
    from sklearn.metrics import mean_absolute_error
    from sklearn.metrics import r2_score
    
    mse = mean_squared_error(_y_pred, _y_test, multioutput='raw_values',squared=False)
    mae = mean_absolute_error(_y_pred, _y_test, multioutput='raw_values')
    r2 = r2_score(_y_pred, _y_test, multioutput='raw_values')
    
    metrics= np.array([mae, mse, r2]).T
    metrics = np.around(metrics, 4)
    
    
    plt.figure(figsize=(20, 10))
    plt.suptitle('ghjkhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh')
    N = len(params)
    M = 2
    for i in range(N):

        plt.subplot(M, N, i + 1)
        plt.title("Корреляционный график")
        plt.xlabel(params[i] + ' Тестовые')
        plt.ylabel(params[i] + ' Предсказанные')
        plt.plot(_y_test[:, i], _y_pred[:, i], '.', alpha = 0.3)


    
    plt.subplot(2, 1, 2)
    ax = plt.gca() 
    fig = plt.gcf()
    
    ax.axis('off')
    table = plt.table(cellText=metrics, colLabels = ['mae', 'mse', 'r2'], rowLabels = params,loc='center', colWidths=[0.1]*3)
    table.set_fontsize(14)
    table.scale(1,2)
    
    
    plt.show()

# %%
regr_model_resume(y_test_array, y_pred)

# %% [markdown]
# ### Проверка иксов

# %%
regr_model_resume(y_test_array, y_pred)

# %%
X_array = X.values
X_pred = X_array[index_th_alg]

# %%
X_pred.shape
# Out:
# (39229, 60)

# %%
X_test_array = np.load(r"C:\Users\trrak\OneDrive\Рабочий стол\InvBloodSolver\df\df_th\X_test_array.npy")
X_test_array.shape
# Out:
# (3923, 60)

# %%
plt.plot(X_test_array[0], '.')
plt.plot(X_pred[0], '.')
plt.xlabel('Индексы')
plt.ylabel('Значения')
plt.title('График y_data')
plt.grid(True)
plt.show()
